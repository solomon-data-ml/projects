# %% [markdown]
# An Exploratory analysis on the house data which gives the insight of relationship between variables

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/data.csv

# %%
df = pd.read_csv('/kaggle/input/data.csv')
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df = df.dropna(axis=0)
df.shape
# Out:
# (0, 81)

# %%
df.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 81 columns]>

# %% [markdown]
# number of unique data

# %%
df.nunique(axis=0)
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 81 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.distplot(df['SalePrice'])
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:200: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /opt/conda/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %% [markdown]
# Clearly there are outliers after 700000 of SalePrice

# %%
corr = df.corr()
plt.figure(figsize=(19, 15))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col1 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col2 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col7 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col8 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row0_col9 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col0 {
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col3 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col5 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col7 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col8 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row1_col9 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col0 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col4 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col5 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col6 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col7 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col0 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col1 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col5 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col6 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col7 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col8 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row3_col9 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col2 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col3 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col6 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row4_col9 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col1 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col2 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col4 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col6 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col7 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col8 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_7bd22a0c_76ff_11ea_91ae_0242ac130202row5_col9 {
#             background-color:  #aec9fc;
#             color:  #000000;
